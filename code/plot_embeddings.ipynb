# %%
from dcwetk.cwe_distance import *
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from frequency_grapher import *

# %%
toks = ['משנה', 'שונה']

# %%
testTok = toks[0]
yrs, wums, _ = getWUMs(testTok)
# Out:
# getting wums...
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
pca = PCA(n_components=3)
pca_wums = [pca.fit_transform(i.u) for i in wums]

# %%
for i, yr in zip(pca_wums, yrs):
    fig, ax = plt.subplots()
    print(yr)
    print(len(i))
    x, y, z = zip(*i)
    ax.scatter(x, y, c=z, cmap='viridis')
    plt.show()
# Out:
# 1880
# 39
# 1885
# 11
# 1890
# 88
# 1895
# 118
# 1900
# 182
# 1905
# 475
# 1910
# 163
# 1915
# 308
# 1920
# 460
# 1925
# 124
# 1930
# 129
# 1935
# 84
# 1940
# 18
# 1945
# 27
